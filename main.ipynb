# %%
import pandas as pd

train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_data.shape
# Out:
# (1460, 81)

# %%
test_data.shape
# Out:
# (1459, 80)

# %%
# Columns available
print("\nColumns in training data:")
print(train_data.columns.tolist())

# Data types and non-null values
print("\nTraining data info:")
train_data.info()
# Out:
# Columns in training data:
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
#📚 Step 4: Data Cleaning (Handling Missing Data)
missing_col=train_data.isnull().sum()[train_data.isnull().sum() > 0]


missing_col
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# 1. Remove Data (Dropping)
# Drop missing rows:
# If only a few rows have missing values and it's not crucial data.
#
# python
# Copy
# Edit
# df.dropna(inplace=True)
# Drop missing columns:
# If a whole column has too many missing values.
#
# python
# Copy
# Edit
# df.drop(columns=['ColumnName'], inplace=True)
# 2. Imputation (Filling Missing Data)
# 👉 Instead of removing, you fill the missing data with some meaningful value.
#
# Options for Imputation:
#
# Fill with Mean (for numeric data):
#
# python
# Copy
# Edit
# df['ColumnName'].fillna(df['ColumnName'].mean(), inplace=True)
# Fill with Median (good for skewed numeric data):
#
# python
# Copy
# Edit
# df['ColumnName'].fillna(df['ColumnName'].median(), inplace=True)
# Fill with Mode (for categorical data):
#
# python
# Copy
# Edit
# df['ColumnName'].fillna(df['ColumnName'].mode()[0], inplace=True)
# Fill with a Constant Value:
#
# python
# Copy
# Edit
# df['ColumnName'].fillna(0, inplace=True)
# # or for categorical:
# df['ColumnName'].fillna('Unknown', inplace=True)
# Forward Fill (ffill) or Backward Fill (bfill): Useful in time series data.
#
# python
# Copy
# Edit
# df.fillna(method='ffill', inplace=True)
# df.fillna(method='bfill', inplace=True)
# 3. Predict Missing Values
# Use a Machine Learning model to predict missing values based on other columns.
#
# Example: Use regression to predict missing house size.
#
# (This is an advanced method. For now, we focus on simpler methods like fill/drop.)

# %%
train_data.shape
# Out:
# (1460, 81)

# %%
# df['ColumnName'].fillna('Unknown', inplace=True)
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259

for col in ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType', 'FireplaceQu']:
   # train_data[col].fillna('None', inplace=True)
   
    if col in train_data.columns:
        train_data.drop(columns=col, inplace=True)



train_data.head()
train_data.shape
# Out:
# (1460, 75)

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
missing_values=train_data.isnull().sum()[train_data.isnull().sum() > 0]
missing_values
# Out:
# LotFrontage     259
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64

# %% [markdown]
# ## 🔷 LotFrontage (259 missing)
# ##Type: Numerical (continuous)
#
# ##Meaning: Linear feet of street connected to property.
#
# ##Best Fix: Fill with median (less sensitive to outliers).
#
# ##python
# train_data['LotFrontage'].fillna(train_data['LotFrontage'].median(), inplace=True)

# %%
train_data['LotFrontage'] = train_data['LotFrontage'].fillna(train_data['LotFrontage'].median())

train_data['LotFrontage'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##🔷 MasVnrArea (8 missing)
#
#
# ##Meaning: Masonry veneer area in square feet.
#
# ##Best Fix: Fill with 0 (if MasVnrType is also missing, it's likely there's no veneer).

# %%
train_data['MasVnrArea'].fillna(0, inplace=True)
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_9428\1635299978.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data['MasVnrArea'].fillna(0, inplace=True)

# %%
train_data['GarageType']=train_data['GarageType'].fillna(0)

# %% [markdown]
#  Basement-related columns:
# These often have missing values because the house has no basement, so:
#
# BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2
#
# Type: Categorical
#
# Fix: Fill with "None" to indicate no basement.

# %%
bsmt_cols = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']
for col in bsmt_cols:
    train_data[col].fillna('None', inplace=True)
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_9428\1214090646.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data[col].fillna('None', inplace=True)

# %% [markdown]
#  Electrical (1 missing)
# Type: Categorical
#
# Best Fix: Fill with mode (most common electrical system).

# %%
train_data['Electrical'].fillna(train_data['Electrical'].mode()[0], inplace=True)
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_9428\383624300.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data['Electrical'].fillna(train_data['Electrical'].mode()[0], inplace=True)

# %% [markdown]
# Garage-related columns:
# These often have missing values because there is no garage.
#
# GarageType, GarageYrBlt, GarageFinish, GarageQual, GarageCond
#
# Fix:
#
# For categorical columns → Fill with "None"
#
# For GarageYrBlt (numerical) → Fill with 0

# %%
garage_cat_cols = ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']
for col in garage_cat_cols:
    train_data[col].fillna('None', inplace=True)

train_data['GarageYrBlt'].fillna(0, inplace=True)
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_9428\3633840480.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data[col].fillna('None', inplace=True)
# C:\Users\santo\AppData\Local\Temp\ipykernel_9428\3633840480.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
missing_values=train_data.isnull().sum()[train_data.isnull().sum() > 0]
missing_values
# Out:
# Series([], dtype: int64)
